# %% [markdown]
# # 0 - Competition
#
# It's a "playground" competition to training our skills in Data Science and Machine Learning field.
#
# **Objective**: Our objective is to have fun with skills. Consequetilly, we have to training the variables  relationship with statistics and other methods.
#
# **Evaluation**: Area Under Curve ROC.
#
# > Submissions are evaluated on [area under the ROC](https://en.wikipedia.org/wiki/Receiver_operating_characteristic) curve between the predicted probability and the observed target.

# %% [markdown]
# # 1. Initial Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None) # Show all columns of dataset

# %% [markdown]
# # 2. Reading data

# %%
sub = pd.read_csv('/kaggle/input/tabular-playground-series-may-2022/sample_submission.csv')
train = pd.read_csv('/kaggle/input/tabular-playground-series-may-2022/train.csv')
test = pd.read_csv('/kaggle/input/tabular-playground-series-may-2022/test.csv')

# %% [markdown]
# We have a train data, where we training our model with a Machine Learning model.

# %%
f'Our training data has {train.shape[0]} rows and {train.shape[1]} cols'
# Out:
# 'Our training data has 900000 rows and 33 cols'

# %%
train.head()
# Out:
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -1.373246  0.238887 -0.243376  0.567405 -0.647715  0.839326  0.113133
# 1   1  1.697021 -1.710322 -2.230332 -0.545661  1.113173 -1.552175  0.447825
# 2   2  1.681726  0.616746 -1.027689  0.810492 -0.609086  0.113965 -0.708660
# 3   3 -0.118172 -0.587835 -0.804638  2.086822  0.371005 -0.128831 -0.282575
# 4   4  1.148481 -0.176567 -0.664871 -1.101343  0.467875  0.500117  0.407515
#
#    f_07  f_08  f_09  f_10  f_11  f_12  f_13  f_14  f_15  f_16  f_17  f_18  \
# 0     1     5     1     3     3     3     1     6     1     0     7     4
# 1     1     3     4     0     2     3     0     1     0     4     6     0
# 2     1     0     2     6     6     4     3     1     2     2     1     4
# 3     3     2     1     0     1     6     4     2     3     3     0     3
# 4     3     3     0     4     3     0     6     0     3     3     1     0
#
# ...

# %% [markdown]
# A test data, where our model we'll testing the metric (AUC ROC) and the variables relationships

# %%
f'Our testing data has {test.shape[0]} rows and {test.shape[1]} cols'
# Out:
# 'Our testing data has 700000 rows and 32 cols'

# %%
test.head()
# Out:
#        id      f_00      f_01      f_02      f_03      f_04      f_05  \
# 0  900000  0.442517  0.174380 -0.999816  0.762741  0.186778 -1.074775
# 1  900001 -0.605598 -0.305715  0.627667 -0.578898 -1.750931  1.355550
# 2  900002  0.303990  2.445110  0.246515  0.818248  0.359731 -1.331845
# 3  900003  0.154053  0.260126 -1.367092 -0.093175 -1.111034 -0.948481
# 4  900004 -1.651904 -0.424266 -0.667356 -0.322124 -0.089462  0.181705
#
#        f_06  f_07  f_08  f_09  f_10  f_11  f_12  f_13  f_14  f_15  f_16  f_17  \
# 0  0.501888     6     6     0     0     0     5     1     1     2     2     0
# 1 -0.190911     1     3     4     0     2     1     3     0     0     0     2
# 2  1.358622     3     3     4     1     1     3     2     2     4     1     0
# 3  1.119220     0     0     4     2     1     5     0     3     3     1     4
# 4  1.784983     2     2     2     0     0     3     0     1     2     0     2
#
# ...

# %% [markdown]
# And a submission file, where the our model will be tested in a real life behavior.

# %%
f'Our submission data has {train.shape[0]} rows and {train.shape[1]} cols'
# Out:
# 'Our submission data has 900000 rows and 33 cols'

# %%
sub.head()
# Out:
#        id  target
# 0  900000     0.5
# 1  900001     0.5
# 2  900002     0.5
# 3  900003     0.5
# 4  900004     0.5

# %% [markdown]
# # 3. Initial considerations
#
# **Variables in dataset**:
#
# 1. **id**: id for each row
# 2. **f_00 ~ f_06, f_19 ~ f_26 and f_28**: quantitative variables
# 3. **f_07 ~ f_18**: discreve quantitative variables
# 4. **f_27**: qualitative variable
# 5. **target**: our predict variable (*what do we want to predict*)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900000 entries, 0 to 899999
# Data columns (total 33 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      900000 non-null  int64
#  1   f_00    900000 non-null  float64
#  2   f_01    900000 non-null  float64
#  3   f_02    900000 non-null  float64
#  4   f_03    900000 non-null  float64
#  5   f_04    900000 non-null  float64
#  6   f_05    900000 non-null  float64
#  7   f_06    900000 non-null  float64
#  8   f_07    900000 non-null  int64
#  9   f_08    900000 non-null  int64
#  10  f_09    900000 non-null  int64
#  11  f_10    900000 non-null  int64
#  12  f_11    900000 non-null  int64
#  13  f_12    900000 non-null  int64
#  14  f_13    900000 non-null  int64
#  15  f_14    900000 non-null  int64
#  16  f_15    900000 non-null  int64
#  17  f_16    900000 non-null  int64
#  18  f_17    900000 non-null  int64
#  19  f_18    900000 non-null  int64
# ...

# %%
train.drop('id', axis = 1).describe()
# Out:
#                 f_00           f_01           f_02           f_03  \
# count  900000.000000  900000.000000  900000.000000  900000.000000
# mean       -0.000286       0.001165       0.001174      -0.001368
# std         0.998888       0.999193       1.000514       1.000175
# min        -4.599856      -4.682199      -4.642676      -4.658816
# 25%        -0.675490      -0.675162      -0.674369      -0.676114
# 50%         0.001144       0.002014       0.002218      -0.002227
# 75%         0.674337       0.675021       0.677505       0.672544
# max         4.749301       4.815699       4.961982       4.454920
#
#                 f_04           f_05           f_06           f_07  \
# count  900000.000000  900000.000000  900000.000000  900000.000000
# mean       -0.000571       0.000284      -0.000709       2.031460
# std         1.000167       0.999875       0.999942       1.656172
# min        -4.748501      -4.750214      -4.842919       0.000000
# ...

# %% [markdown]
# # 4. Baseline model
#
# A baseline model it's a simple model, nothing more than this. If we create a robust model and her non beat the baseline model, we use a simple model.
#
# Without knowing much about the data, let's just put a logistic regression as a baseline without any very absurd parameters.
#
# From previous works, I know that it is good to use the standard scaler to have some very OK results.
#
# So... Let's load some librarys 🙆‍♂️

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score

# %%
log_reg = LogisticRegression(max_iter = 900, random_state = 42)
scaler = StandardScaler()
ohe = OneHotEncoder()

# %%
numeric_cols = list(train.select_dtypes(include=['float64']).columns)
# categorical_cols = list(train.select_dtypes(include=['object']).columns) # Change to other encoder

# %%
# train[numeric_cols] = scaler.fit_transform(train[numeric_cols].to_numpy())
# train[categorical_cols] = ohe.fit_transform(train[categorical_cols].to_numpy())

# %%
# X = train.drop('target', axis = 1)
# y = train['target']

# %%
# cross_val_score(estimator = log_reg, cv = 5, X = X, y = y)
